# %%
import requests
from bs4 import BeautifulSoup
from persiantools.jdatetime import JalaliDateTime
import datetime
from datetime import timedelta
import json
import re 
from typing import List, Dict, Optional,Any
import time
from requests.exceptions import RequestException
import logging
import pprint

import os
os.environ['PYTHONIOENCODING'] = 'utf-8'

# %%
persian_months = {
    'فروردین': 1,
    'اردیبهشت': 2,
    'خرداد': 3,
    'تیر': 4,
    'مرداد': 5,
    'شهریور': 6,
    'مهر': 7,
    'آبان': 8,
    'آذر': 9,
    'دی': 10,
    'بهمن': 11,
    'اسفند': 12
}

# %%
# Define the URL of the news page
url = "https://mihanblockchain.com/category/news/"

# Define headers to mimic a real user (this helps to avoid bot detection)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}

# Send a GET request to the URL with the headers
response = requests.get(url, headers=headers)

# %%
# Initialize a list to store the result
result = []

# Get the current time using datetime.now(datetime.UTC)
# current_time = datetime.datetime.now(datetime.UTC)
current_time =  datetime.datetime.now(datetime.timezone.utc)

# Check if the request was successful
if response.status_code == 200:
    # Parse the page content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')

    # Select the articles using the provided CSS selectors
    articles = soup.select('div.jnews_category_content_wrapper > div.jeg_postblock_4.jeg_postblock > div.jeg_posts.jeg_block_container > div.jeg_posts > article.jeg_post')

    # Extract the link and date for each article
    for article in articles:
        # Extract the link
        link = article.select_one('div.jeg_postblock_content > div.jeg_post_meta > div.jeg_meta_date > a')['href']
        
        # Extract the date
        date_str = article.select_one('div.jeg_postblock_content > div.jeg_post_meta > div.jeg_meta_date').get_text(strip=True)
        
        # Convert Persian date string to Gregorian datetime
        try:
            # Split the date and time parts
            persian_date, persian_time = date_str.split(" - ")
            
            # Split the Persian date into day, month, and year
            day, month_name, year = persian_date.split()
            
            # Map the Persian month name to the month number
            month = persian_months[month_name]
            
            # Convert the Persian date to a format that strptime can parse
            converted_date = f"{year}-{month:02d}-{int(day):02d}"
            
            # Parse the converted date into JalaliDateTime object
            persian_datetime = JalaliDateTime.strptime(converted_date, '%Y-%m-%d')

            # Add the time information
            hour, minute = map(int, persian_time.split(":"))
            persian_datetime = persian_datetime.replace(hour=hour, minute=minute)

            # Convert to Gregorian date
            gregorian_datetime = persian_datetime.to_gregorian()

            # Convert to UTC (remove Persian Standard Time offset)
            utc_datetime = gregorian_datetime.replace(tzinfo=None)

            # Get the date difference between the article's date and the current time
            time_diff = current_time - utc_datetime.replace(tzinfo=datetime.timezone.utc)

            # Only add the article if it was published within the last 1 day
            if time_diff <= timedelta(days=8):
                # Format the datetime into a string
                formatted_date = utc_datetime.strftime('%Y-%m-%d %H:%M:%S')

                # Append the link and formatted date to the result list
                result.append({
                    "link": link,
                    "date": formatted_date
                })

        except Exception as e:
            print(f"Error converting date: {e}")
else:
    print("Failed to retrieve the webpage")

# %%
json_result = json.dumps(result, ensure_ascii=False, indent=4)

# %%
type(json_result)
# Out:
# str

# %%
# Initialize a list to store the detailed results
detailed_result = []

if isinstance(json_result, str):
    json_result = json.loads(json_result)

# Loop through each article in the previous result
for article in json_result:
    url = article['link']
    date = article['date']  # Date from the last result
    
    # Send a GET request to the URL with headers
    response = requests.get(url, headers=headers)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the page content with BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the data content, keeping the HTML tags
        data = soup.select_one('div.jeg_inner_content')
        data_html = data.decode_contents() if data else "N/A"  # Raw HTML content

        # Extract the creator
        creator = soup.select_one('div.jeg_meta_container > div.jeg_post_meta.jeg_post_meta_1 > div.meta_left > div.jeg_meta_author > a')
        creator_name = creator.get_text(strip=True) if creator else "N/A"  # Use "N/A" if no creator found

        # Extract the title
        title = soup.select_one('div.jeg_inner_content > div.entry-header > h1.jeg_post_title')
        title_text = title.get_text(strip=True) if title else "N/A"  # Use "N/A" if no title found

        # Add the extracted fields to the result
        detailed_result.append({
            "link": url,
            "date": date,  # Date from the last JSON
            "data": data_html,  # Keep HTML tags
            "creator": creator_name,
            "title": title_text
        })
    else:
        print(f"Failed to retrieve the article at {url}")

# Convert the detailed result list to a JSON string
json_detailed_result = json.dumps(detailed_result, ensure_ascii=False, indent=4)

# Print the detailed JSON result
print(json_detailed_result)
# Out:
# [
#     {
#         "link": "https://mihanblockchain.com/onchain-ui-would-prevent-bybit-hack-dfinity/",
#         "date": "2025-03-01 15:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">میهن بلاکچین</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">اخبار</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/public/\">اخبار عمومی</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">نظر بنیان‌گذار Dfinity پس از هک بای بیت: برنامه‌ها باید کاملا آنچین باشند</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> نگارش:‌</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">رضا حضرتی</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/onchain-ui-would-prevent-bybit-hack-dfinity/\">11 اسفند 1403 - 15:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">در</span>\n<a href=\"https://mihanblockchain.com/category/news/public/\" rel=\"category tag\">اخبار عمومی</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tزمان مطالعه: 2 دقیقه\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/onchain-ui-would-prevent-bybit-hack-dfinity/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"صرافی بای بیت\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-150x77.jpg 150w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"صرافی بای بیت\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-150x77.jpg 150w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_article jnews_content_top_ads\"><div class=\"ads-wrapper\"></div></div>\n<div class=\"entry-content no-share\">\n<div class=\"jeg_share_button share-float jeg_sticky_share clearfix share-monocrhome\">\n<div class=\"jeg_share_float_container\"></div> </div>\n<div class=\"content-inner\">\n<div class=\"jeg_ad jeg_ad_article jnews_content_inline_ads\"><div class=\"ads-wrapper align-right\"></div></div>\n<p> ...
#         "creator": "رضا حضرتی",
#         "title": "نظر بنیان‌گذار Dfinity پس از هک بای بیت: برنامه‌ها باید کاملا آنچین باشند"
#     },
#     {
#         "link": "https://mihanblockchain.com/coinbase-case-dropped-by-u-s-sec/",
#         "date": "2025-03-01 14:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">میهن بلاکچین</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">اخبار</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/public/\">اخبار عمومی</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">شکایت از کوین بیس توسط SEC «به‌طور کامل» کنار گذاشته شد</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> نگارش:‌</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">رضا حضرتی</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/coinbase-case-dropped-by-u-s-sec/\">11 اسفند 1403 - 14:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">در</span>\n<a href=\"https://mihanblockchain.com/category/news/public/\" rel=\"category tag\">اخبار عمومی</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tزمان مطالعه: 2 دقیقه\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/coinbase-case-dropped-by-u-s-sec/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-scaled.webp\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"کوین بیس و SEC\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-750x385.webp\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-750x385.webp 750w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-300x154.webp 300w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-1024x526.webp 1024w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-768x394.webp 768w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-1536x788.webp 1536w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-2048x1051.webp 2048w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-1140x585.webp 1140w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"کوین بیس و SEC\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-750x385.webp\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-750x385.webp 750w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-300x154.webp 300w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-1024x526.webp 1024w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-768x394.webp 768w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-1536x788.webp 1536w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-2048x1051.webp 2048w, https://mihanblockchain.com/wp-content/uploads/2025/02/CoinbaseSec-1140x585.webp 1140w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_article jnews_content_top_ads\"><div class=\"ads-wrapper\"></div></div>\n<div class=\"entry-content no-share\">\n<d ...
#         "creator": "رضا حضرتی",
#         "title": "شکایت از کوین بیس توسط SEC «به‌طور کامل» کنار گذاشته شد"
#     },
#     {
#         "link": "https://mihanblockchain.com/solana-price-rebounds-after-drop-reached-bottom/",
#         "date": "2025-03-01 13:30:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">ÙÛÙÙ Ø¨ÙØ§Ú©ÚÛÙ</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">Ø§Ø®Ø¨Ø§Ø±</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/altcoin/\">Ø§Ø®Ø¨Ø§Ø± Ø¢ÙØªÚ©ÙÛÙ</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">Ø¨Ø§Ø²Ú¯Ø´Øª ÙÛÙØª Ø³ÙÙØ§ÙØ§ Ù¾Ø³ Ø§Ø² Ø±ÛØ²Ø´ Ø¹ÙÛÙØ Ø¢ÛØ§ Ø¨Ù Ú©Ù Ø±Ø³ÛØ¯ÛÙØ</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> ÙÚ¯Ø§Ø±Ø´:â</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">Ø±Ø¶Ø§ Ø­Ø¶Ø±ØªÛ</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/solana-price-rebounds-after-drop-reached-bottom/\">11 Ø§Ø³ÙÙØ¯ 1403 - 13:30</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">Ø¯Ø±</span>\n<a href=\"https://mihanblockchain.com/category/news/altcoin/\" rel=\"category tag\">Ø§Ø®Ø¨Ø§Ø± Ø¢ÙØªÚ©ÙÛÙ</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tØ²ÙØ§Ù ÙØ·Ø§ÙØ¹Ù: 2 Ø¯ÙÛÙÙ\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/solana-price-rebounds-after-drop-reached-bottom/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana.jpg\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"ÙÛÙØª Ø§Ø±Ø² Ø¯ÛØ¬ÛØªØ§Ù SOL Ø´Ø¨Ú©Ù Ø³ÙÙØ§ÙØ§ Solana\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana.jpg\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana-150x77.jpg 150w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"ÙÛÙØª Ø§Ø±Ø² Ø¯ÛØ¬ÛØªØ§Ù SOL Ø´Ø¨Ú©Ù Ø³ÙÙØ§ÙØ§ Solana\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana.jpg\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ§-Solana-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/05/Ø§Ø±Ø²-Ø¯ÛØ¬ÛØªØ§Ù-SOL-Ø´Ø¨Ú©Ù-Ø³ÙÙØ§ÙØ ...
#         "creator": "Ø±Ø¶Ø§ Ø­Ø¶Ø±ØªÛ",
#         "title": "Ø¨Ø§Ø²Ú¯Ø´Øª ÙÛÙØª Ø³ÙÙØ§ÙØ§ Ù¾Ø³ Ø§Ø² Ø±ÛØ²Ø´ Ø¹ÙÛÙØ Ø¢ÛØ§ Ø¨Ù Ú©Ù Ø±Ø³ÛØ¯ÛÙØ"
#     },
#     {
#         "link": "https://mihanblockchain.com/ujudge-dismisses-sec-fraud-lawsuit-hex-founder/",
#         "date": "2025-03-01 13:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">میهن بلاکچین</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">اخبار</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/public/\">اخبار عمومی</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">پیروزی ریچارد هارت، بنیان‌‌گذار Hex، در برابر SEC؛ رد شکایت ۱ میلیارد دلاری در دادگاه آمریکا</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> نگارش:‌</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">رضا حضرتی</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/ujudge-dismisses-sec-fraud-lawsuit-hex-founder/\">11 اسفند 1403 - 13:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">در</span>\n<a href=\"https://mihanblockchain.com/category/news/public/\" rel=\"category tag\">اخبار عمومی</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tزمان مطالعه: 2 دقیقه\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/ujudge-dismisses-sec-fraud-lawsuit-hex-founder/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs.jpg\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"سازمان امور مالیات IRS صرافی کراکن دادگاه kraken\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs.jpg\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs-768x395.jpg 768w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"سازمان امور مالیات IRS صرافی کراکن دادگاه kraken\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs.jpg\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2021/05/court-orders-kraken-to-provide-information-on-user-transactions-to-the-irs-768x395.jpg 768w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_article jnews_content_top_ads\"><div class=\"ads-wrapper\"></div></div>\n<div class=\"entry-content no-share\">\n<div class=\"jeg_share_button share-float jeg_sticky_sha ...
#         "creator": "رضا حضرتی",
#         "title": "پیروزی ریچارد هارت، بنیان‌‌گذار Hex، در برابر SEC؛ رد شکایت ۱ میلیارد دلاری در دادگاه آمریکا"
#     },
#     {
#         "link": "https://mihanblockchain.com/trump-to-host-crypto-summit-in-march-2025/",
#         "date": "2025-03-01 12:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">میهن بلاکچین</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">اخبار</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/public/\">اخبار عمومی</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">برگزاری نشست کریپتو در کاخ سفید در ۷ مارس؛ سخنرانی ترامپ در میان چهر‌ه‌های کلیدی</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> نگارش:‌</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">رضا حضرتی</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/trump-to-host-crypto-summit-in-march-2025/\">11 اسفند 1403 - 12:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">در</span>\n<a href=\"https://mihanblockchain.com/category/news/public/\" rel=\"category tag\">اخبار عمومی</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tزمان مطالعه: 1 دقیقه\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/trump-to-host-crypto-summit-in-march-2025/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2025/02/trump--scaled.webp\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2025/02/trump--scaled.webp\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2025/02/trump--scaled.webp 2560w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--300x154.webp 300w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--1024x526.webp 1024w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--768x394.webp 768w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--1536x788.webp 1536w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--2048x1051.webp 2048w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--835x429.webp 835w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2025/02/trump--scaled.webp\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2025/02/trump--scaled.webp 2560w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--300x154.webp 300w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--1024x526.webp 1024w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--768x394.webp 768w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--1536x788.webp 1536w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--2048x1051.webp 2048w, https://mihanblockchain.com/wp-content/uploads/2025/02/trump--835x429.webp 835w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_article jnews_content_top_ads\"><div class=\"ads-wrapper\"></div></div>\n<div class=\"entry-content no-share\">\n<div class=\"jeg_share_button share-float jeg_sticky_share clearfix share-mono ...
#         "creator": "رضا حضرتی",
#         "title": "برگزاری نشست کریپتو در کاخ سفید در ۷ مارس؛ سخنرانی ترامپ در میان چهر‌ه‌های کلیدی"
#     },
#     {
#         "link": "https://mihanblockchain.com/blackrock-adds-btc-etf-150-b-model-portfolio/",
#         "date": "2025-03-01 11:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">میهن بلاکچین</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">اخبار</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/bitcoin/\">اخبار بیت کوین</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">بلک‌راک صندوق ETF بیت کوین را به محصول سبد سرمایه‌گذاری مدل ۱۵۰ میلیارد دلاری خود اضافه کرد</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> نگارش:‌</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">رضا حضرتی</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/blackrock-adds-btc-etf-150-b-model-portfolio/\">11 اسفند 1403 - 11:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">در</span>\n<a href=\"https://mihanblockchain.com/category/news/bitcoin/\" rel=\"category tag\">اخبار بیت کوین</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tزمان مطالعه: 1 دقیقه\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/blackrock-adds-btc-etf-150-b-model-portfolio/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-scaled.webp\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"فیچر ETF بیت کوین و خود بیت کوین\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-scaled.webp\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-scaled.webp 2560w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-300x154.webp 300w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-1024x526.webp 1024w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-768x394.webp 768w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-1536x788.webp 1536w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-2048x1051.webp 2048w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-835x429.webp 835w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"فیچر ETF بیت کوین و خود بیت کوین\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-scaled.webp\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-scaled.webp 2560w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-300x154.webp 300w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-1024x526.webp 1024w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-768x394.webp 768w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-1536x788.webp 1536w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-2048x1051.webp 2048w, https://mihanblockchain.com/wp-content/uploads/2025/01/bitcoin-etfs-835x429.webp 835w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_ ...
#         "creator": "رضا حضرتی",
#         "title": "بلک‌راک صندوق ETF بیت کوین را به محصول سبد سرمایه‌گذاری مدل ۱۵۰ میلیارد دلاری خود اضافه کرد"
#     },
#     {
#         "link": "https://mihanblockchain.com/cme-group-launch-solana-futures-etf-momentum/",
#         "date": "2025-03-01 10:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">ÙÛÙÙ Ø¨ÙØ§Ú©ÚÛÙ</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">Ø§Ø®Ø¨Ø§Ø±</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/altcoin/\">Ø§Ø®Ø¨Ø§Ø± Ø¢ÙØªÚ©ÙÛÙ</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">Ø±Ø§ÙâØ§ÙØ¯Ø§Ø²Û ÙØ¹Ø§ÙÙØ§Øª ÙÛÙÚØ±Ø² Ø³ÙÙØ§ÙØ§ Ø¯Ø± Ø¨Ø§Ø²Ø§Ø± ÙØ´ØªÙØ§Øª CME GroupØ Ø§ÙØ²Ø§ÛØ´ Ø§Ø­ØªÙØ§Ù ØªØ§ÛÛØ¯ ETFÙØ§Û Ø§Ø³Ù¾Ø§Øª SOL</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> ÙÚ¯Ø§Ø±Ø´:â</span><a href=\"https://mihanblockchain.com/author/ahmadi-alefgmail-com/\">Ø§ÙÛØ±Ø­Ø³ÛÙ Ø§Ø­ÙØ¯Û</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/cme-group-launch-solana-futures-etf-momentum/\">11 Ø§Ø³ÙÙØ¯ 1403 - 10:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">Ø¯Ø±</span>\n<a href=\"https://mihanblockchain.com/category/news/altcoin/\" rel=\"category tag\">Ø§Ø®Ø¨Ø§Ø± Ø¢ÙØªÚ©ÙÛÙ</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tØ²ÙØ§Ù ÙØ·Ø§ÙØ¹Ù: 2 Ø¯ÙÛÙÙ\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/cme-group-launch-solana-futures-etf-momentum/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"ÙÛÚØ± ETF Ø³ÙÙØ§ÙØ§\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-150x77.jpg 150w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"ÙÛÚØ± ETF Ø³ÙÙØ§ÙØ§\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-150x77.jpg 150w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_article jnews_content_top_ads\"><div class=\"ads-wrapper\"></div></div>\n<div class=\"entry-content no-share\">\n<div clas ...
#         "creator": "Ø§ÙÛØ±Ø­Ø³ÛÙ Ø§Ø­ÙØ¯Û",
#         "title": "Ø±Ø§ÙâØ§ÙØ¯Ø§Ø²Û ÙØ¹Ø§ÙÙØ§Øª ÙÛÙÚØ±Ø² Ø³ÙÙØ§ÙØ§ Ø¯Ø± Ø¨Ø§Ø²Ø§Ø± ÙØ´ØªÙØ§Øª CME GroupØ Ø§ÙØ²Ø§ÛØ´ Ø§Ø­ØªÙØ§Ù ØªØ§ÛÛØ¯ ETFÙØ§Û Ø§Ø³Ù¾Ø§Øª SOL"
#     },
#     {
#         "link": "https://mihanblockchain.com/btc-rebounds-after-pce-90k-next/",
#         "date": "2025-03-01 09:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">ÙÛÙÙ Ø¨ÙØ§Ú©ÚÛÙ</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">Ø§Ø®Ø¨Ø§Ø±</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/bitcoin/\">Ø§Ø®Ø¨Ø§Ø± Ø¨ÛØª Ú©ÙÛÙ</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">Ø¨Ø§Ø²Ú¯Ø´Øª ÙÛÙØª Ø¨ÛØª Ú©ÙÛÙ Ù¾Ø³ Ø§Ø² Ø§ÙØªØ´Ø§Ø± Ø¯Ø§Ø¯ÙâÙØ§Û PCEØ ÙØ¯Ù Ø¨Ø¹Ø¯Û Û¹Û°Ù¬Û°Û°Û° Ø¯ÙØ§Ø± Ø§Ø³ØªØ</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> ÙÚ¯Ø§Ø±Ø´:â</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">Ø±Ø¶Ø§ Ø­Ø¶Ø±ØªÛ</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/btc-rebounds-after-pce-90k-next/\">11 Ø§Ø³ÙÙØ¯ 1403 - 09:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">Ø¯Ø±</span>\n<a href=\"https://mihanblockchain.com/category/news/bitcoin/\" rel=\"category tag\">Ø§Ø®Ø¨Ø§Ø± Ø¨ÛØª Ú©ÙÛÙ</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tØ²ÙØ§Ù ÙØ·Ø§ÙØ¹Ù: 1 Ø¯ÙÛÙÙ\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/btc-rebounds-after-pce-90k-next/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20.jpg\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"ØªØ­ÙÛÙ ÙÛÙØª Ø¨ÛØª Ú©ÙÛÙ\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20.jpg\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20-835x429.jpg 835w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"ØªØ­ÙÛÙ ÙÛÙØª Ø¨ÛØª Ú©ÙÛÙ\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20.jpg\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/02/fsb-imf-and-bis-papers-to-set-global-crypto-framework-says-g20-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2023/02/fsb- ...
#         "creator": "Ø±Ø¶Ø§ Ø­Ø¶Ø±ØªÛ",
#         "title": "Ø¨Ø§Ø²Ú¯Ø´Øª ÙÛÙØª Ø¨ÛØª Ú©ÙÛÙ Ù¾Ø³ Ø§Ø² Ø§ÙØªØ´Ø§Ø± Ø¯Ø§Ø¯ÙâÙØ§Û PCEØ ÙØ¯Ù Ø¨Ø¹Ø¯Û Û¹Û°Ù¬Û°Û°Û° Ø¯ÙØ§Ø± Ø§Ø³ØªØ"
#     },
#     {
#         "link": "https://mihanblockchain.com/findings-bybit-hack-problem-was-safewallet/",
#         "date": "2025-02-27 21:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">ÙÛÙÙ Ø¨ÙØ§Ú©ÚÛÙ</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">Ø§Ø®Ø¨Ø§Ø±</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/public/\">Ø§Ø®Ø¨Ø§Ø± Ø¹ÙÙÙÛ</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">ÛØ§ÙØªÙâÙØ§Û Ø¬Ø¯ÛØ¯ Ø¯Ø± ÙÙØ±Ø¯ ÙÚ© Ø¨Ø§Û Ø¨ÛØªØ ÙØ´Ú©Ù Ø§Ø² SafeWallet Ø¨ÙØ¯!</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> ÙÚ¯Ø§Ø±Ø´:â</span><a href=\"https://mihanblockchain.com/author/reza-hazrati/\">Ø±Ø¶Ø§ Ø­Ø¶Ø±ØªÛ</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/findings-bybit-hack-problem-was-safewallet/\">9 Ø§Ø³ÙÙØ¯ 1403 - 21:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">Ø¯Ø±</span>\n<a href=\"https://mihanblockchain.com/category/news/public/\" rel=\"category tag\">Ø§Ø®Ø¨Ø§Ø± Ø¹ÙÙÙÛ</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tØ²ÙØ§Ù ÙØ·Ø§ÙØ¹Ù: 1 Ø¯ÙÛÙÙ\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/findings-bybit-hack-problem-was-safewallet/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"ØµØ±Ø§ÙÛ Ø¨Ø§Û Ø¨ÛØª\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-150x77.jpg 150w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"ØµØ±Ø§ÙÛ Ø¨Ø§Û Ø¨ÛØª\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2023/11/bybit-150x77.jpg 150w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_article jnews_content_top_ads\"><div class=\"ads-wrapper\"></div></div>\n<div class=\"entry-content no-share\">\n<div class=\"jeg_share_button share-float jeg_sticky_share clearfix share-monocrhome\">\n<div class=\"jeg_share_float_container\"></div> </div>\n<div class=\"content-inner\">\n<div class=\ ...
#         "creator": "Ø±Ø¶Ø§ Ø­Ø¶Ø±ØªÛ",
#         "title": "ÛØ§ÙØªÙâÙØ§Û Ø¬Ø¯ÛØ¯ Ø¯Ø± ÙÙØ±Ø¯ ÙÚ© Ø¨Ø§Û Ø¨ÛØªØ ÙØ´Ú©Ù Ø§Ø² SafeWallet Ø¨ÙØ¯!"
#     },
#     {
#         "link": "https://mihanblockchain.com/dtcc-lists-solana-futures-etfs-fueling-hopes/",
#         "date": "2025-02-27 20:00:00",
#         "data": "\n<div class=\"jeg_breadcrumbs jeg_breadcrumb_container\">\n<div id=\"breadcrumbs\"><span class=\"\">\n<a href=\"https://mihanblockchain.com\">میهن بلاکچین</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"\">\n<a href=\"https://mihanblockchain.com/category/news/\">اخبار</a>\n</span><i class=\"fa fa-angle-left\"></i><span class=\"breadcrumb_last_link\">\n<a href=\"https://mihanblockchain.com/category/news/altcoin/\">اخبار آلتکوین</a>\n</span></div> </div>\n<div class=\"entry-header\">\n<h1 class=\"jeg_post_title\">نمایش ETFهای فیوچرز سولانا در فهرست DTCC؛ افزایش احتمال راه‌اندازی ETFهای سولانا</h1>\n<div class=\"jeg_meta_container\"><div class=\"jeg_post_meta jeg_post_meta_1\">\n<div class=\"meta_left\">\n<div class=\"jeg_meta_author coauthor\">\n<span class=\"meta_text\"> نگارش:‌</span><a href=\"https://mihanblockchain.com/author/ahmadi-alefgmail-com/\">امیرحسین احمدی</a> </div>\n<div class=\"jeg_meta_date\">\n<a href=\"https://mihanblockchain.com/dtcc-lists-solana-futures-etfs-fueling-hopes/\">9 اسفند 1403 - 20:00</a>\n</div>\n<div class=\"jeg_meta_category\">\n<span><span class=\"meta_text\">در</span>\n<a href=\"https://mihanblockchain.com/category/news/altcoin/\" rel=\"category tag\">اخبار آلتکوین</a> </span>\n</div>\n<div class=\"jeg_meta_reading_time\">\n<span>\n\t\t\t            \tزمان مطالعه: 2 دقیقه\n\t\t\t            </span>\n</div> </div>\n<div class=\"meta_right\">\n<div class=\"jeg_meta_comment\"><a href=\"https://mihanblockchain.com/dtcc-lists-solana-futures-etfs-fueling-hopes/#respond\"><i class=\"fa fa-comment-o\"></i> 0</a></div>\n</div>\n</div>\n</div>\n</div>\n<div class=\"jeg_featured featured_image\"><a href=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg\"><div class=\"thumbnail-container\" style=\"padding-bottom:51.333%\"><img alt=\"فیچر ETF سولانا\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" data-lazy-sizes=\"(max-width: 750px) 100vw, 750px\" data-lazy-src=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg\" data-lazy-srcset=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-150x77.jpg 150w\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" src=\"data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20750%20385'%3E%3C/svg%3E\" width=\"750\"><noscript><img alt=\"فیچر ETF سولانا\" class=\"attachment-jnews-featured-750 size-jnews-featured-750 wp-post-image\" decoding=\"async\" fetchpriority=\"high\" height=\"385\" sizes=\"(max-width: 750px) 100vw, 750px\" src=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg\" srcset=\"https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana.jpg 1200w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-300x154.jpg 300w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-1024x526.jpg 1024w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-768x394.jpg 768w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-835x429.jpg 835w, https://mihanblockchain.com/wp-content/uploads/2024/07/etf_solana-150x77.jpg 150w\" width=\"750\"/></noscript></img></div></a></div>\n<div class=\"jeg_share_top_container\"></div>\n<div class=\"jeg_ad jeg_article jnews_content_top_ads\"><div class=\"ads-wrapper\"></div></div>\n<div class=\"entry-content no-share\">\n<div class=\"jeg_share_button share-float jeg_sticky_share clearfix share-monocrhome\">\n<div class=\"jeg_share_float_container\"></div> </div>\n<div class=\"content-inner\">\n<p>دو صندوق  ...
#         "creator": "امیرحسین احمدی",
#         "title": "نمایش ETFهای فیوچرز سولانا در فهرست DTCC؛ افزایش احتمال راه‌اندازی ETFهای سولانا"
#     }
# ]

# %%
def upload_image_to_api(image_url: str) -> str:
    """
    Uploads an image to an API and returns the new URL.
    Replace this with your actual API call.
    """
    try:
        # Download the image from the original URL
        response = requests.get(image_url, stream=True)
        response.raise_for_status()

        # Simulate API upload (replace with real API endpoint)
        # For this example, assume the API accepts a file and returns {'url': 'new_url'}
        api_endpoint = "https://capitalino.io/api/admin/upload-image/ai-save-image"  # Replace with your API URL
        files = {'file': (image_url.split('/')[-1], response.content)}
        api_response = requests.post(api_endpoint, files=files)
        api_response.raise_for_status()

        # Extract new URL from API response
        new_url = api_response.json().get('url')
        return new_url
    except requests.RequestException as e:
        print(f"Error uploading image {image_url}: {e}")
        return image_url  # Return original URL if upload fails

# %%
def process_json_items(items: List[Dict]) -> List[Dict]:
    html_content = items[0].get('data', '')
    if not html_content:
        return [{'json': {'error': 'No HTML content found in items[0].data'}}]

    excluded_containers = [
        "jeg_share_bottom_container",
        "jeg_ad_jeg_article_jnews_content_bottom_ads",
        "jnews_prev_next_container",
        "jnews_author_box_container",
        "jnews_related_post_container",
        "jeg_postblock_22 jeg_postblock jeg_module_hook jeg_pagination_disable jeg_col_2o3 jnews_module_307974_0_67c8441ee8156",
        "jnews_popup_post_container",
        "jnews_comment_container"
    ]

    def is_in_excluded_container(html: str, element_position: int) -> bool:
        sample_text = html[element_position:element_position + 100]
        for container in excluded_containers:
            pattern = rf'<div[^>]*class="[^"]*{container}[^"]*"[^>]*>[\\s\\S]*?{re.escape(sample_text)}'
            if re.search(pattern, html, re.IGNORECASE):
                return True
        return False
    
    def extract_thumbnail_image(html: str) -> str:
        """
        Extracts the thumbnail image URL from the HTML content using the specified CSS selector.
        div.jeg_inner_content > div.jeg_featured > a > div.thumbnail-container > img (src)
        """
        try:
            # First try to find data-lazy-src attribute which contains the actual image URL
            thumbnail_pattern = r'<div[^>]*class="[^"]*jeg_featured[^"]*"[^>]*>.*?<a[^>]*>.*?<div[^>]*class="[^"]*thumbnail-container[^"]*"[^>]*>.*?<img[^>]*data-lazy-src="([^"]+)"'
            thumbnail_match = re.search(thumbnail_pattern, html, re.DOTALL)
            
            if thumbnail_match:
                return thumbnail_match.group(1)
            
            # If data-lazy-src is not found, try data-src
            thumbnail_pattern = r'<div[^>]*class="[^"]*jeg_featured[^"]*"[^>]*>.*?<a[^>]*>.*?<div[^>]*class="[^"]*thumbnail-container[^"]*"[^>]*>.*?<img[^>]*data-src="([^"]+)"'
            thumbnail_match = re.search(thumbnail_pattern, html, re.DOTALL)
            
            if thumbnail_match:
                return thumbnail_match.group(1)
            
            # If neither data-lazy-src nor data-src is found, try srcset
            thumbnail_pattern = r'<div[^>]*class="[^"]*jeg_featured[^"]*"[^>]*>.*?<a[^>]*>.*?<div[^>]*class="[^"]*thumbnail-container[^"]*"[^>]*>.*?<img[^>]*data-lazy-srcset="([^"]+)"'
            thumbnail_match = re.search(thumbnail_pattern, html, re.DOTALL)
            
            if thumbnail_match:
                # srcset contains multiple URLs, take the first one
                srcset = thumbnail_match.group(1)
                first_url = srcset.split(',')[0].strip().split(' ')[0]
                return first_url
            
            # As a last resort, try the regular src attribute
            thumbnail_pattern = r'<div[^>]*class="[^"]*jeg_featured[^"]*"[^>]*>.*?<a[^>]*>.*?<div[^>]*class="[^"]*thumbnail-container[^"]*"[^>]*>.*?<img[^>]*src="([^"]+)"'
            thumbnail_match = re.search(thumbnail_pattern, html, re.DOTALL)
            
            if thumbnail_match:
                src = thumbnail_match.group(1)
                # Skip data URLs
                if src.startswith('data:'):
                    return None
                return src
                
            return None
        except Exception as e:
            print(f"Error extracting thumbnail image: {e}")
            return None

    def extract_and_replace_images(html: str) -> tuple[str, List[Dict]]:
        processed_html = html
        images_url = []
        processed_urls = set()
        image_counter = 0

        # Pattern for div.content-inner > div.wp-block-image > figure > a > img
        figure_pattern = r'<div[^>]*class="[^"]*wp-block-image[^"]*"[^>]*>\s*<figure[^>]*>\s*<a[^>]*>\s*<img[^>]*?(?:data-lazy-src="([^"]+)"|data-src="([^"]+)"|src="([^"]+)").*?</a>(?:\s*<figcaption[^>]*>([\s\S]*?)</figcaption>)?[\s\S]*?</figure>'
        
        for figure_match in re.finditer(figure_pattern, html, re.IGNORECASE):
            full_match = figure_match.group(0)
            match_position = figure_match.start()
            
            # Try to get the image URL from data-lazy-src, data-src, or src in that order
            image_url = figure_match.group(1) or figure_match.group(2) or figure_match.group(3)
            
            # Skip data URLs
            if image_url and image_url.startswith('data:'):
                # Try to find data-lazy-srcset in the match
                srcset_match = re.search(r'data-lazy-srcset="([^"]+)"', full_match)
                if srcset_match:
                    # Extract the first URL from srcset
                    srcset = srcset_match.group(1)
                    image_url = srcset.split(',')[0].strip().split(' ')[0]
                else:
                    continue  # Skip this image if we can't find a valid URL

            if not image_url or is_in_excluded_container(html, match_position) or image_url in processed_urls:
                continue

            # Caption is now in group 4 due to the additional capturing groups
            caption = figure_match.group(4)
            if caption:
                caption = re.sub(r'<[^>]+>', '', caption).strip()

            image_id = f'image{image_counter}'
            placeholder = f'**image_{image_id}**'

            images_url.append({
                'id': image_id,
                'url': image_url,
                'caption': caption,
                'type': 'figure'
            })

            processed_html = processed_html.replace(full_match, placeholder)
            processed_urls.add(image_url)
            image_counter += 1

        return processed_html, images_url

    def extract_content(html: str) -> List[str]:
        # First, find the main content div
        content_div_pattern = r'<div[^>]*class="[^"]*content-inner[^"]*"[^>]*>([\s\S]*?)<div[^>]*class="[^"]*jeg_share_bottom_container'
        content_div_match = re.search(content_div_pattern, html, re.IGNORECASE)
        
        if not content_div_match:
            return []
        
        content_html = content_div_match.group(1)
        
        # Replace image placeholders to ensure they're preserved
        content_html = re.sub(r'<div[^>]*>\s*(\*\*image_image\d+\*\*)\s*</div>', r'\1', content_html, flags=re.IGNORECASE)
        
        # Extract paragraphs, blockquotes, and image placeholders
        content_pattern = r'(<p[^>]*>[\s\S]*?</p>|<blockquote[^>]*>[\s\S]*?</blockquote>|<h[1-6][^>]*>[\s\S]*?</h[1-6]>|\*\*image_image\d+\*\*)'
        content_array = []

        for match in re.finditer(content_pattern, content_html, re.IGNORECASE):
            content = match.group(1).strip()
            
            # If it's an image placeholder, add it directly
            if content.startswith('**image_'):
                content_array.append(content)
            else:
                # For text content, strip HTML tags but preserve the text
                text_content = re.sub(r'<[^>]+>', '', content).strip()
                if text_content:
                    content_array.append(text_content)

        return content_array

    def extract_tags(html: str) -> List[str]:
        """
        Extracts tags from the HTML content using the specified CSS selector:
        div.inner-content > div.jeg_post_tags > a
        """
        try:
            # First try the specified path
            tag_section_pattern = r'<div[^>]*class="[^"]*inner-content[^"]*"[^>]*>.*?<div[^>]*class="[^"]*jeg_post_tags[^"]*"[^>]*>([\s\S]*?)</div>'
            tag_section_match = re.search(tag_section_pattern, html, re.DOTALL)
        
            # If not found, try an alternative pattern
            if not tag_section_match:
                tag_section_pattern = r'<div[^>]*class="[^"]*jeg_post_tags[^"]*"[^>]*>([\s\S]*?)</div>'
                tag_section_match = re.search(tag_section_pattern, html, re.DOTALL)
        
            if not tag_section_match:
                return []

            tags = []
            tag_pattern = r'<a[^>]*>([\s\S]*?)</a>'
            for tag_match in re.finditer(tag_pattern, tag_section_match.group(1), re.IGNORECASE):
                tag_text = tag_match.group(1).strip()
                # Remove any HTML tags inside the tag text
                tag_text = re.sub(r'<[^>]+>', '', tag_text).strip()
                if tag_text and not tag_text.lower() == 'تگ:':  # Skip the "تگ:" label if present
                    tags.append(tag_text)
        
            return tags
        except Exception as e:
            print(f"Error extracting tags: {e}")
            return []

    # Extract thumbnail image first
    thumbnail_image = extract_thumbnail_image(html_content)
    
    # Extract and process images
    processed_html, images_url = extract_and_replace_images(html_content)
    
    # Extract text content and metadata without unicode_escape processing
    title = items[0].get('title', '')
    raw_date = items[0].get('date')
    creator = items[0].get('creator', '')
    content = extract_content(processed_html)
    tags = extract_tags(html_content)

    # Upload thumbnail image if found
    if thumbnail_image:
        new_thumbnail_url = upload_image_to_api(thumbnail_image)
        thumbnail_image = new_thumbnail_url
    else:
        # Use the first image as thumbnail if no dedicated thumbnail is found
        thumbnail_image = images_url[0]['url'] if images_url else None

    # Upload content images and replace URLs
    for image in images_url:
        original_url = image['url']
        new_url = upload_image_to_api(original_url)
        image['url'] = new_url  # Replace original URL with new URL

    return [{
        'json': {
            'title': title,
            'date': raw_date,
            'creator': creator,
            'thumbnailImage': thumbnail_image,
            'content': content,
            'ImagesUrl': images_url,
            'tags': tags
        }
    }]

# %%
# Parse the JSON string into a Python object
items = json.loads(json_detailed_result)

# Process the items
result = process_json_items(items)
# Out:
# Error uploading image https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg: 400 Client Error: Bad Request for url: https://capitalino.io/api/admin/upload-image/ai-save-image
# Error uploading image https://mihanblockchain.com/wp-content/uploads/2025/03/image-3.png: 400 Client Error: Bad Request for url: https://capitalino.io/api/admin/upload-image/ai-save-image
# Error uploading image https://mihanblockchain.com/wp-content/uploads/2025/03/image-4-1024x569.png: 502 Server Error: Bad Gateway for url: https://capitalino.io/api/admin/upload-image/ai-save-image

# %%
# Convert the result to JSON format
output_json = json.dumps(result, ensure_ascii=False, indent=4)

# Output the JSON
print(output_json)
# Out:
# [
#     {
#         "json": {
#             "title": "نظر بنیان‌گذار Dfinity پس از هک بای بیت: برنامه‌ها باید کاملا آنچین باشند",
#             "date": "2025-03-01 15:00:00",
#             "creator": "رضا حضرتی",
#             "thumbnailImage": "https://mihanblockchain.com/wp-content/uploads/2023/11/bybit.jpg",
#             "content": [
#                 "دومینیک ویلیامز (Dominic Williams)، بنیان‌گذار و دانشمند ارشد بنیاد دفینیتی (Dfinity Foundation)، یک سازمان غیرانتفاعی که توسعه و نگهداری پروتکل اینترنت کامپیوتر (Internet Computer Protocol – ICP) را بر عهده دارد، اخیراً در گفت‌وگویی اظهار داشت که برنامه‌ها باید به‌طور کاملا آنچین باشند تا از وقوع حملاتی مشابه هک اخیر بای‌بیت (Bybit) که باعث به خطر افتادن رابط کاربری شد، جلوگیری شود.\nبه گزارش میهن بلاکچین، ویلیامز توضیح داد که بیشتر برنامه‌های غیرمتمرکز و پروژه‌های بلاکچینی کنونی دارای اقتصاد توکنی آنچین هستند اما برای زیرساخت‌های خود به پلتفرم‌های متمرکز مانند آمازون وب سرویس (Amazon Web Services – AWS) متکی هستند.\n\n\n\nلزوم انتقال برنامه‌ها به آنچین\nاین وابستگی، آن‌ها را در برابر حملات امنیتی متمرکز آسیب‌پذیر می‌کند. بنیان‌گذار دفینیتی در این گفت‌وگو اظهار داشت:\n\n\n\n\nکل هدف اجرای نرم‌افزار روی بلاکچین این است که تضمین کند منطق از پیش تعیین‌شده، روی داده‌های صحیح آنچین اجرا می‌شود. اما شما با فناوری اطلاعات سنتی این تضمین را ندارید.",
#                 "وی در ادامه افزود: \n\n\n\n\nما در این صنعت راه خود را گم کرده‌ایم. چیزهایی را آنچین می‌نامیم که روی AWS ساخته شده‌اند؛ آن هم فقط به این دلیل که یک توکن مرتبط دارند.",
#                 "ویلیامز اظهار داشت که هرگونه به‌روزرسانی کد در یک پروژه یا پلتفرم باید از طریق یک سازمان مستقل غیرمتمرکز (DAO) انجام شود و تحت بررسی جامعه کاربران قرار گیرد، نه اینکه یک توسعه‌دهنده به‌تنهایی کد را منتشر کند.\n\n\n**image_image0**\nتأثیر اقتصادی حملات امنیتی متمرکز بر بازار کریپتو\nدانشمند ارشد دفینیتی سپس به تأثیر مالی هک ۱.۴ میلیارد دلاری بای‌بیت بر بازارهای کریپتو پرداخت.\n\n\n\nویلیامز اظهار داشت گروه هکری لازاروس (Lazarus Hacker Group) که تحت حمایت یک دولت است، در پول‌شویی مهارت زیادی دارد و این سرمایه‌ها از بازار کریپتو خارج شده و به سایر بخش‌های اقتصادی منتقل می‌شوند و دیگر به بازار بازنمی‌گردند.\n\n\n\nوی افزود:\n\n\n\n\nاین دقیقاً یکی از دلایلی است که باعث اصلاح قیمت‌ها در بازار امروز شده است.",
#                 "پس از هک اخیر بای‌بیت و افزایش بلاتکلیفی کلان‌اقتصادی، ارزش کل بازار ارزهای دیجیتال کاهش شدیدی را تجربه کرد.\n\n\n**image_image1**\nطبق داده‌های کوین مارکت کپ، ارزش کل بازار کریپتو در حال حاضر ۲.۸ تریلیون دلار است که از اوج ۳.۶۲ تریلیون دلاری ثبت‌شده در ژانویه ۲۰۲۵ کاهش یافته است.\n\n\n\nقیمت ارزهای دیجیتال پس از هک بای‌بیت که بزرگ‌ترین حمله هکری تاریخ کریپتو محسوب می‌شود، به‌شدت کاهش یافت. این اصلاح عمیق، در کنار بلاتکلیفی کلان‌اقتصادی و کاهش اعتماد سرمایه‌گذاران به این حوزه نوپا، موجب فشار مضاعف بر بازار شد.\n\n\n\nبودان اوپریشکو (Bohdan Opryshko)، مدیر عملیاتی اوراستیک (Everstake) نیز گفت که حمله بای‌بیت باعث شده است استیکرهای نهادی (Institutional Stakers) به دلیل نگرانی‌های امنیتی از پلتفرم‌های متمرکز خارج شوند.\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\nمنبع:\nCointelegraph\n\nتگ: امنیتتکنولوژی بلاک چینصرافی ارز دیجیتال"
#             ],
#             "ImagesUrl": [
#                 {
#                     "id": "image0",
#                     "url": "https://mihanblockchain.com/wp-content/uploads/2025/03/image-3.png",
#                     "caption": "پروتکل اینترنت کامپیوتر به‌وسیله قراردادهای هوشمند، کل برنامه‌ها را به‌صورت آنچین میزبانی می‌کند تا یکپارچگی داده‌ها را حتی در هنگام ارتقاها تضمین کند – منبع: پروتکل اینترنت کامپیوتر",
#                     "type": "figure"
#                 },
#                 {
#                     "id": "image1",
#                     "url": "https://mihanblockchain.com/wp-content/uploads/2025/03/image-4-1024x569.png",
#                     "caption": "منبع: کوین مارکت کپ (CoinMarketCap)",
#                     "type": "figure"
#                 }
#             ],
#             "tags": [
#                 "امنیت",
#                 "تکنولوژی بلاک چین",
#                 "صرافی ارز دیجیتال"
#             ]
#         }
#     }
# ]

# %%
class APIClient:
    def __init__(self, base_url: str, api_key: str = None, max_retries: int = 3):
        """
        Initialize the API client
        
        Args:
            base_url (str): The base URL of the API
            api_key (str, optional): API key if required
            max_retries (int): Maximum number of retry attempts for failed requests
        """
        self.base_url = base_url.rstrip('/')
        self.api_key = api_key
        self.max_retries = max_retries
        self.session = requests.Session()
        
        # Setup headers
        self.headers = {
            'Content-Type': 'application/json',
            'Accept': 'application/json'
        }
        if api_key:
            self.headers['Authorization'] = f'Bearer {api_key}'
            
        # Setup logging
        logging.basicConfig(level=logging.INFO)
        self.logger = logging.getLogger(__name__)

    def post_news_data(self, data: Dict[str, Any]) -> Dict:
        """
        Post news data to the API
        
        Args:
            data (Dict[str, Any]): The news data to send
            
        Returns:
            Dict: The API response
            
        Raises:
            RequestException: If the request fails after all retries
        """
        endpoint = '/api/news'  # Adjust this endpoint based on your API
        url = f"{self.base_url}{endpoint}"
        
        for attempt in range(self.max_retries):
            try:
                self.logger.info(f"Sending data to {url} (Attempt {attempt + 1}/{self.max_retries})")
                response = self.session.post(
                    url=url,
                    json=data,
                    headers=self.headers
                )
                
                response.raise_for_status()
                self.logger.info("Successfully sent data to API")
                return response.json()
                
            except RequestException as e:
                self.logger.error(f"Attempt {attempt + 1} failed: {str(e)}")
                if attempt == self.max_retries - 1:
                    raise
                time.sleep(2 ** attempt)  # Exponential backoff
                
        raise RequestException("Failed to send data after all retry attempts")

# %%
# Usage example:
try:
    # Initialize the API client
    api_client = APIClient(
        base_url="YOUR_API_BASE_URL",  # Replace with your API base URL
        api_key="YOUR_API_KEY"         # Replace with your API key if required
    )
    
    # Send each item in output_json to the API
    for item in output_json:
        try:
            response = api_client.post_news_data(item)
            print(f"Successfully sent item with title: {item.get('title', 'Unknown')}")
            print(f"API Response: {response}")
            
        except RequestException as e:
            print(f"Failed to send item: {str(e)}")
            continue
            
except Exception as e:
    print(f"An error occurred: {str(e)}")
